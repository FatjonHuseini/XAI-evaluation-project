# %%
import pandas as pd

# %%
df=pd.read_csv("values.csv", header=[0])
df
x=df["label"]
print(x)
print(type(x))
y=x.to_numpy()
# Out:
# 0       positive
# 1       negative
# 2       positive
# 3       positive
# 4        neutral
#           ...
# 3483     neutral
# 3484    negative
# 3485    positive
# 3486     neutral
# 3487    positive
# Name: label, Length: 3488, dtype: object
# <class 'pandas.core.series.Series'>

# %%
print(y)
# Out:
# ['positive' 'negative' 'positive' ... 'positive' 'neutral' 'positive']

# %%
import random
new_values=[]
random.shuffle(y)

# %%
print(y)
# Out:
# ['neutral' 'positive' 'neutral' ... 'neutral' 'positive' 'neutral']

# %%
new_series = pd.Series(y)
new_series
# Out:
# 0        neutral
# 1       positive
# 2        neutral
# 3       negative
# 4       positive
#           ...
# 3483    positive
# 3484     neutral
# 3485     neutral
# 3486    positive
# 3487     neutral
# Length: 3488, dtype: object

# %%
df
# Out:
#          label
# 0      neutral
# 1     positive
# 2      neutral
# 3     negative
# 4     positive
# ...        ...
# 3483  positive
# 3484   neutral
# 3485   neutral
# 3486  positive
# 3487   neutral
#
# [3488 rows x 1 columns]

# %%
df["new_column"] = ""
df
# Out:
#          label new_column
# 0      neutral
# 1     positive
# 2      neutral
# 3     negative
# 4     positive
# ...        ...        ...
# 3483  positive
# 3484   neutral
# 3485   neutral
# 3486  positive
# 3487   neutral
#
# [3488 rows x 2 columns]

# %%
df["new_column"] = new_series

# %%
df

# %%
df.to_csv("values.csv")
